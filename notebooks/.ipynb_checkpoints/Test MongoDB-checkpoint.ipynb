# %%
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pymongo
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.fantasy_football

# %%
collection = db.player_data
collection.find_one({},{"history":1})
# Out:
# {'_id': ObjectId('58975a961d41c866864073c3'),
#  'history': [{'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 8,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 1,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-08-14T15:00:00Z',
#    'kickoff_time_formatted': '14 Aug 16:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 9,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 1,
#    'saves': 0,
#    'selected': 6064,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 4,
#    'team_h_score': 3,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': 0,
#    'transfers_in': 0,
#    'transfers_out': 0,
#    'value': 50,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 13,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 526,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-08-20T16:30:00Z',
#    'kickoff_time_formatted': '20 Aug 17:30',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 8,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 2,
#    'saves': 0,
#    'selected': 7400,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 0,
#    'team_h_score': 0,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -578,
#    'transfers_in': 153,
#    'transfers_out': 731,
#    'value': 50,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 28,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 1066,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-08-27T14:00:00Z',
#    'kickoff_time_formatted': '27 Aug 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 18,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 3,
#    'saves': 0,
#    'selected': 7708,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 3,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -571,
#    'transfers_in': 150,
#    'transfers_out': 721,
#    'value': 50,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 31,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 1616,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-09-10T14:00:00Z',
#    'kickoff_time_formatted': '10 Sep 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 13,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 4,
#    'saves': 0,
#    'selected': 8072,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 2,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -449,
#    'transfers_in': 183,
#    'transfers_out': 632,
#    'value': 49,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 43,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 2197,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-09-17T14:00:00Z',
#    'kickoff_time_formatted': '17 Sep 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 7,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 5,
#    'saves': 0,
#    'selected': 8379,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 4,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -158,
#    'transfers_in': 172,
#    'transfers_out': 330,
#    'value': 49,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 51,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 2781,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-09-24T16:30:00Z',
#    'kickoff_time_formatted': '24 Sep 17:30',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 4,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 6,
#    'saves': 0,
#    'selected': 8632,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 0,
#    'team_h_score': 3,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -269,
#    'transfers_in': 158,
#    'transfers_out': 427,
#    'value': 49,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 61,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 3367,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-10-02T15:30:00Z',
#    'kickoff_time_formatted': '02 Oct 16:30',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 3,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 7,
#    'saves': 0,
#    'selected': 8699,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 0,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -253,
#    'transfers_in': 106,
#    'transfers_out': 359,
#    'value': 49,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 71,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 3956,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-10-15T14:00:00Z',
#    'kickoff_time_formatted': '15 Oct 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 16,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 8,
#    'saves': 0,
#    'selected': 8856,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 2,
#    'team_h_score': 3,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -256,
#    'transfers_in': 88,
#    'transfers_out': 344,
#    'value': 49,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 81,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 4548,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-10-22T14:00:00Z',
#    'kickoff_time_formatted': '22 Oct 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 12,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 9,
#    'saves': 0,
#    'selected': 8844,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 0,
#    'team_h_score': 0,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -200,
#    'transfers_in': 48,
#    'transfers_out': 248,
#    'value': 48,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 97,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 5142,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-10-29T11:30:00Z',
#    'kickoff_time_formatted': '29 Oct 12:30',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 15,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 10,
#    'saves': 0,
#    'selected': 8863,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 4,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -161,
#    'transfers_in': 40,
#    'transfers_out': 201,
#    'value': 48,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 101,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 5740,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-11-06T12:00:00Z',
#    'kickoff_time_formatted': '06 Nov 12:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 17,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 11,
#    'saves': 0,
#    'selected': 8861,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -165,
#    'transfers_in': 61,
#    'transfers_out': 226,
#    'value': 48,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 113,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 6339,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-11-19T12:30:00Z',
#    'kickoff_time_formatted': '19 Nov 12:30',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 11,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 12,
#    'saves': 0,
#    'selected': 8975,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -127,
#    'transfers_in': 73,
#    'transfers_out': 200,
#    'value': 48,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 121,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 6940,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-11-27T14:15:00Z',
#    'kickoff_time_formatted': '27 Nov 14:15',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 2,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 13,
#    'saves': 0,
#    'selected': 9003,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 3,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -81,
#    'transfers_in': 46,
#    'transfers_out': 127,
#    'value': 48,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 140,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 7544,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-12-03T17:30:00Z',
#    'kickoff_time_formatted': '03 Dec 17:30',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 20,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 14,
#    'saves': 0,
#    'selected': 9042,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 5,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -86,
#    'transfers_in': 55,
#    'transfers_out': 141,
#    'value': 48,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 141,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 8149,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-12-10T15:00:00Z',
#    'kickoff_time_formatted': '10 Dec 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 14,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 15,
#    'saves': 0,
#    'selected': 9068,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 3,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -88,
#    'transfers_in': 57,
#    'transfers_out': 145,
#    'value': 48,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 156,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 8759,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-12-13T19:45:00Z',
#    'kickoff_time_formatted': '13 Dec 19:45',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 6,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 16,
#    'saves': 0,
#    'selected': 9084,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 2,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -53,
#    'transfers_in': 42,
#    'transfers_out': 95,
#    'value': 48,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 164,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 9373,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-12-18T16:00:00Z',
#    'kickoff_time_formatted': '18 Dec 16:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 10,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 17,
#    'saves': 0,
#    'selected': 9086,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 2,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -60,
#    'transfers_in': 23,
#    'transfers_out': 83,
#    'value': 48,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 171,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 9989,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2016-12-26T15:00:00Z',
#    'kickoff_time_formatted': '26 Dec 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 19,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 18,
#    'saves': 0,
#    'selected': 9114,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 0,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -95,
#    'transfers_in': 27,
#    'transfers_out': 122,
#    'value': 47,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 181,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 10607,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2017-01-01T16:00:00Z',
#    'kickoff_time_formatted': '01 Jan 16:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 5,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 19,
#    'saves': 0,
#    'selected': 9142,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 0,
#    'team_h_score': 2,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -62,
#    'transfers_in': 35,
#    'transfers_out': 97,
#    'value': 47,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 191,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 11229,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2017-01-03T19:45:00Z',
#    'kickoff_time_formatted': '03 Jan 19:45',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 2,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 20,
#    'saves': 0,
#    'selected': 9140,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 3,
#    'team_h_score': 3,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -48,
#    'transfers_in': 28,
#    'transfers_out': 76,
#    'value': 47,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 207,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 11853,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2017-01-14T15:00:00Z',
#    'kickoff_time_formatted': '14 Jan 15:00',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 16,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 21,
#    'saves': 0,
#    'selected': 9236,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 4,
#    'team_h_score': 0,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -102,
#    'transfers_in': 71,
#    'transfers_out': 173,
#    'value': 47,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 211,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 12484,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2017-01-22T14:15:00Z',
#    'kickoff_time_formatted': '22 Jan 14:15',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 3,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 22,
#    'saves': 0,
#    'selected': 9231,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 2,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -96,
#    'transfers_in': 40,
#    'transfers_out': 136,
#    'value': 47,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 221,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 13118,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2017-01-31T19:45:00Z',
#    'kickoff_time_formatted': '31 Jan 19:45',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 18,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 23,
#    'saves': 0,
#    'selected': 9269,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 2,
#    'team_h_score': 1,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -66,
#    'transfers_in': 33,
#    'transfers_out': 99,
#    'value': 47,
#    'was_home': True,
#    'winning_goals': 0,
#    'yellow_cards': 0},
#   {'assists': 0,
#    'attempted_passes': 0,
#    'big_chances_created': 0,
#    'big_chances_missed': 0,
#    'bonus': 0,
#    'bps': 0,
#    'clean_sheets': 0,
#    'clearances_blocks_interceptions': 0,
#    'completed_passes': 0,
#    'creativity': '0.0',
#    'dribbles': 0,
#    'ea_index': 0,
#    'element': 1,
#    'errors_leading_to_goal': 0,
#    'errors_leading_to_goal_attempt': 0,
#    'fixture': 231,
#    'fouls': 0,
#    'goals_conceded': 0,
#    'goals_scored': 0,
#    'ict_index': '0.0',
#    'id': 13761,
#    'influence': '0.0',
#    'key_passes': 0,
#    'kickoff_time': '2017-02-04T12:30:00Z',
#    'kickoff_time_formatted': '04 Feb 12:30',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'minutes': 0,
#    'offside': 0,
#    'open_play_crosses': 0,
#    'opponent_team': 4,
#    'own_goals': 0,
#    'penalties_conceded': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'recoveries': 0,
#    'red_cards': 0,
#    'round': 24,
#    'saves': 0,
#    'selected': 9274,
#    'tackled': 0,
#    'tackles': 0,
#    'target_missed': 0,
#    'team_a_score': 1,
#    'team_h_score': 3,
#    'threat': '0.0',
#    'total_points': 0,
#    'transfers_balance': -34,
#    'transfers_in': 12,
#    'transfers_out': 46,
#    'value': 47,
#    'was_home': False,
#    'winning_goals': 0,
#    'yellow_cards': 0}]}

# %%
players = collection.find({},{"history":1})

# %%
player_dfs = {}
for i, player in enumerate(players):
    df = pd.DataFrame(player["history"])
    df.index = df["round"]
    player_dfs[i] = df

# %%
panel = pd.Panel(player_dfs)

# %%
panel[0].columns
# Out:
# Index(['assists', 'attempted_passes', 'big_chances_created',
#        'big_chances_missed', 'bonus', 'bps', 'clean_sheets',
#        'clearances_blocks_interceptions', 'completed_passes', 'creativity',
#        'dribbles', 'ea_index', 'element', 'errors_leading_to_goal',
#        'errors_leading_to_goal_attempt', 'fixture', 'fouls', 'goals_conceded',
#        'goals_scored', 'ict_index', 'id', 'influence', 'key_passes',
#        'kickoff_time', 'kickoff_time_formatted', 'loaned_in', 'loaned_out',
#        'minutes', 'offside', 'open_play_crosses', 'opponent_team', 'own_goals',
#        'penalties_conceded', 'penalties_missed', 'penalties_saved',
#        'recoveries', 'red_cards', 'round', 'saves', 'selected', 'tackled',
#        'tackles', 'target_missed', 'team_a_score', 'team_h_score', 'threat',
#        'total_points', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'winning_goals', 'yellow_cards'],
#       dtype='object')

# %%
x = panel[:,:,["clearances_blocks_interceptions"]].sum(axis=1).astype(np.float64)
y = panel[:,:,["errors_leading_to_goal", "errors_leading_to_goal_attempt"]].sum(axis=1).sum().astype(np.float64)
#xy += np.random.uniform(-0.5, 0.5, xy.shape)
sns.regplot(x.values.ravel(), y.values.ravel(), x_jitter=1, y_jitter=.5)

# %%
x = panel[:,:,["dribbles"]].sum(axis=1).astype(np.float64)
y = panel[:,:,["tackled"]].sum(axis=1).astype(np.float64)
#xy += np.random.uniform(-0.5, 0.5, xy.shape)
sns.regplot(x.values.ravel(), y.values.ravel(), x_jitter=1, y_jitter=1)

# %%
x = panel[:,:,["attempted_passes"]].sum(axis=1).astype(np.float64)
y = panel[:,:,["completed_passes"]].sum(axis=1).astype(np.float64)
#xy += np.random.uniform(-0.5, 0.5, xy.shape)
sns.regplot(x.values.ravel(), y.values.ravel(), x_jitter=1, y_jitter=1)

# %%
panel[273].columns
# Out:
# Index(['assists', 'attempted_passes', 'big_chances_created',
#        'big_chances_missed', 'bonus', 'bps', 'clean_sheets',
#        'clearances_blocks_interceptions', 'completed_passes', 'creativity',
#        'dribbles', 'ea_index', 'element', 'errors_leading_to_goal',
#        'errors_leading_to_goal_attempt', 'fixture', 'fouls', 'goals_conceded',
#        'goals_scored', 'ict_index', 'id', 'influence', 'key_passes',
#        'kickoff_time', 'kickoff_time_formatted', 'loaned_in', 'loaned_out',
#        'minutes', 'offside', 'open_play_crosses', 'opponent_team', 'own_goals',
#        'penalties_conceded', 'penalties_missed', 'penalties_saved',
#        'recoveries', 'red_cards', 'round', 'saves', 'selected', 'tackled',
#        'tackles', 'target_missed', 'team_a_score', 'team_h_score', 'threat',
#        'total_points', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'winning_goals', 'yellow_cards'],
#       dtype='object')

# %%
panel.loc[:,:,"errors_leading_to_goal"].sum().add(panel.loc[:,:,"errors_leading_to_goal_attempt"].sum()).sort_values(ascending=False).head()
# Out:
# 681    5.0
# 410    5.0
# 32     5.0
# 381    5.0
# 774    3.0
# dtype: float64

# %%
panel.loc[:,:,"tackled"].sum().div(panel.loc[:,:,"minutes"].sum()).sort_values(ascending=False).head()
# Out:
# 254    1.000000
# 400    0.157895
# 259    0.125000
# 545    0.102041
# 566    0.100000
# dtype: float64

# %%
panel.loc[:,:,"dribbles"].sum().div(panel.loc[:,:,"minutes"].sum()).sort_values(ascending=False).head(8)
# Out:
# 729    0.333333
# 80     0.333333
# 566    0.150000
# 564    0.085520
# 448    0.076923
# 446    0.073684
# 552    0.073509
# 89     0.062500
# dtype: float64

# %%
df = pd.DataFrame({"pass": panel.loc[:,:,"completed_passes"].sum().div(panel.loc[:,:,"attempted_passes"].sum()),
                   "att": panel.loc[:,:,"attempted_passes"].sum()})
sns.regplot(df["att"], df["pass"])

# %%
df.sort_values("att", ascending=False).dropna()
# Out:
#         att      pass
# 202  2002.0  0.861638
# 504  1692.0  0.851655
# 263  1558.0  0.881258
# 727  1455.0  0.877663
# 78   1455.0  0.877663
# 401  1408.0  0.884943
# 96   1397.0  0.877595
# 745  1397.0  0.877595
# 192  1390.0  0.853957
# 221  1364.0  0.826979
# 231  1345.0  0.874349
# 209  1342.0  0.806259
# 88   1329.0  0.881114
# 737  1329.0  0.881114
# 664  1321.0  0.869039
# 15   1321.0  0.869039
# 38   1316.0  0.882979
# 687  1316.0  0.882979
# 311  1293.0  0.849961
# 234  1278.0  0.864632
# 395  1272.0  0.801101
# 25   1250.0  0.891200
# 674  1250.0  0.891200
# 653  1198.0  0.873122
# 4    1198.0  0.873122
# 194  1197.0  0.836257
# 227  1183.0  0.867287
# 386  1173.0  0.846547
# 728  1168.0  0.882705
# 79   1168.0  0.882705
# ..      ...       ...
# 259    13.0  0.769231
# 642    12.0  0.583333
# 230    11.0  0.909091
# 545    11.0  1.000000
# 446    11.0  0.818182
# 448    10.0  0.500000
# 89     10.0  1.000000
# 633    10.0  0.700000
# 658    10.0  0.900000
# 738    10.0  1.000000
# 9      10.0  0.900000
# 583     8.0  1.000000
# 744     7.0  1.000000
# 95      7.0  1.000000
# 488     7.0  0.857143
# 622     6.0  0.833333
# 703     6.0  0.833333
# 54      6.0  0.833333
# 719     5.0  0.600000
# 70      5.0  0.600000
# 580     5.0  0.200000
# 594     4.0  0.750000
# 621     3.0  1.000000
# 729     3.0  0.666667
# 80      3.0  0.666667
# 420     2.0  0.000000
# 636     2.0  0.500000
# 484     2.0  1.000000
# 604     1.0  1.000000
# 522     1.0  0.000000
#
# [596 rows x 2 columns]

# %%
collection = db.player_details
collection.find_one({"elements": {"$elemMatch": {"id": 3}}}, {"elements.$":1})
# Out:
# {'_id': ObjectId('589b8fbc1d41c860fe1289b6'),
#  'elements': [{'assists': 1,
#    'bonus': 17,
#    'bps': 543,
#    'chance_of_playing_next_round': 100,
#    'chance_of_playing_this_round': 100,
#    'clean_sheets': 7,
#    'code': 51507,
#    'cost_change_event': 0,
#    'cost_change_event_fall': 0,
#    'cost_change_start': 3,
#    'cost_change_start_fall': -3,
#    'creativity': '36.9',
#    'dreamteam_count': 3,
#    'ea_index': 493,
#    'element_type': 2,
#    'ep_next': '6.3',
#    'ep_this': '4.3',
#    'event_points': 1,
#    'first_name': 'Laurent',
#    'form': '4.8',
#    'goals_conceded': 24,
#    'goals_scored': 2,
#    'ict_index': '86.2',
#    'id': 3,
#    'in_dreamteam': False,
#    'influence': '610.2',
#    'loaned_in': 0,
#    'loaned_out': 0,
#    'loans_in': 0,
#    'loans_out': 0,
#    'minutes': 2043,
#    'news': '',
#    'now_cost': 63,
#    'own_goals': 0,
#    'penalties_missed': 0,
#    'penalties_saved': 0,
#    'photo': '51507.jpg',
#    'points_per_game': '4.2',
#    'red_cards': 0,
#    'saves': 0,
#    'second_name': 'Koscielny',
#    'selected_by_percent': '17.2',
#    'special': False,
#    'squad_number': 6,
#    'status': 'a',
#    'team': 1,
#    'team_code': 3,
#    'threat': '212.0',
#    'total_points': 97,
#    'transfers_in': 867287,
#    'transfers_in_event': 4880,
#    'transfers_out': 497706,
#    'transfers_out_event': 20174,
#    'value_form': '0.8',
#    'value_season': '15.4',
#    'web_name': 'Koscielny',
#    'yellow_cards': 3}]}
